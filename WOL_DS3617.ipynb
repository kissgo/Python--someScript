# %%
import requests
from bs4 import BeautifulSoup


loginUrl="http://"
url="http://"

mac=""
#mac1=

# %%
loginData={
    "luci_username": "",
    "luci_password": ""
}

# %%
s = requests.session()
res = s.post(url=loginUrl,data=loginData)

# %%
res.encoding=res.apparent_encoding

soup=BeautifulSoup(res.text,features="lxml")

# %%
soup.contents
# Out:
# ['html',
#  <html lang="zh-cn">
#  <head>
#  <meta charset="utf-8"/>
#  <title>MiRouter - 概览 - LuCI</title>
#  <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=0" name="viewport"/>
#  <meta content="telephone=no, email=no" name="format-detection"/>
#  <meta content="yes" name="apple-mobile-web-app-capable"/>
#  <meta content="yes" name="mobile-web-app-capable"/>
#  <meta content="true" name="x5-fullscreen"/>
#  <meta content="yes" name="full-screen"/>
#  <meta content="app" name="x5-page-mode"/>
#  <meta content="application" name="browsermode"/>
#  <meta content="#282828" name="theme-color"/>
#  <meta content="no" name="msapplication-tap-highlight"/>
#  <meta content="#282828" name="msapplication-TileColor"/>
#  <meta content="MiRouter - LuCI" name="application-name"/>
#  <meta content="MiRouter - LuCI" name="apple-mobile-web-app-title"/>
#  <meta content="/luci-static/argon/logo.png" name="msapplication-TileImage"/>
#  <link href="/luci-static/argon/logo.png" rel="icon" sizes="144x144"/>
#  <link href="/luci-static/argon/logo.png" rel="apple-touch-icon-precomposed" sizes="144x144"/>
#  <link href="/luci-static/argon/css/style.css?v=1.0" rel="stylesheet"/>
#  <link href="/luci-static/argon/favicon.ico" rel="shortcut icon"/>
#  <script src="/luci-static/resources/xhr.js?v=1.0"></script>
#  <script src="/luci-static/argon/js/jquery.min.js?v=1.0"></script>
#  </head>
#  <body class="lang_zh-cnOverview logged-in">
#  <header>
#  <div class="container">
#  <span class="showSide"></span>
#  <a class="brand" href="#">MiRouter</a>
#  <div class="pull-right">
#  <a class="uci_change_indicator label notice" href="/cgi-bin/luci/admin/uci/changes?redir=">未保存的配置: 5</a>
#  <span id="xhr_poll_status" onclick="XHR.running() ? XHR.halt() : XHR.run()" style="display:none">
#  <span class="label success" id="xhr_poll_status_on"><span class="mobile-hide">自动刷新</span> 开</span>
#  <span class="label" id="xhr_poll_status_off" style="display:none"><span class="mobile-hide">自动刷新</span> 关</span>
#  </span>
#  </div>
#  </div>
#  </header>
#  <div class="main">
#  <div class="loading" style="display:none"><span><div class="loading-img"></div>Loading...</span></div>
#  <div class="main-left">
#  <ul class="nav"><li class="slide"><a class="menu" data-title="状态" href="#">状态</a><ul class="slide-menu"><li><a data-title="概览" href="/cgi-bin/luci/admin/status/overview">概览</a></li><li><a data-title="防火墙" href="/cgi-bin/luci/admin/status/iptables">防火墙</a></li><li><a data-title="路由表" href="/cgi-bin/luci/admin/status/routes">路由表</a></li><li><a data-title="系统日志" href="/cgi-bin/luci/admin/status/syslog">系统日志</a></li><li><a data-title="内核日志" href="/cgi-bin/luci/admin/status/dmesg">内核日志</a></li><li><a data-title="系统进程" href="/cgi-bin/luci/admin/status/processes">系统进程</a></li><li><a data-title="实时信息" href="/cgi-bin/luci/admin/status/realtime">实时信息</a></li><li><a data-title="负载均衡" href="/cgi-bin/luci/admin/status/mwan">负载均衡</a></li><li><a data-title="释放内存" href="/cgi-bin/luci/admin/status/release_ram">释放内存</a></li></ul></li><li class="slide"><a class="menu" data-title="系统" href="#">系统</a><ul class="slide-menu"><li><a data-title="Web 管理" href="/cgi-bin/luci/admin/system/webadmin">Web 管理</a></li><li><a data-title="系统" href="/cgi-bin/luci/admin/system/system">系统</a></li><li><a data-title="管理权" href="/cgi-bin/luci/admin/system/admin">管理权</a></li><li><a data-title="软件包" href="/cgi-bin/luci/admin/system/packages">软件包</a></li><li><a data-title="TTYD 终端" href="/cgi-bin/luci/admin/system/terminal">TTYD 终端</a></li><li><a data-title="启动项" href="/cgi-bin/luci/admin/system/startup">启动项</a></li><li><a data-title="计划任务" href="/cgi-bin/luci/admin/system/crontab">计划任务</a></li><li><a data-title="挂载点" href="/cgi-bin/luci/admin/system/fstab">挂载点</a></li><li><a data-title="LED 配置" href="/cgi-bin/luci/admin/system/leds">LED 配置</a></li><li><a data-title="备份/升级" href="/cgi-bin/luci/admin/system/flashops">备份/升级</a></li><li><a data-title="定时重启" href="/cgi-bin/luci/admin/system/autoreboot">定时重启</a></li><li><a data-title="文件传输" href="/cgi-bin/luci/admin/system/filetransfer">文件传输</a></li><li><a data-title="重启" href="/cgi-bin/luci/admin/system/reboot">重启</a></li></ul></li><li class="slide"><a class="menu" data-title="服务" href="#">服务</a><ul class="slide-menu"><li><a data-title="广告屏蔽大师 Plus+" href="/cgi-bin/luci/admin/services/adbyby">广告屏蔽大师 Plus+</a></li><li><a data-title="AdGuard Home" href="/cgi-bin/luci/admin/services/AdGuardHome">AdGuard Home</a></li><li><a data-title="Hello World" href="/cgi-bin/luci/admin/services/vssr">Hello World</a></li><li><a data-title="上网时间控制" href="/cgi-bin/luci/admin/services/mia">上网时间控制</a></li><li><a data-title="OpenClash" href="/cgi-bin/luci/admin/services/openclash">OpenClash</a></li><li><a data-title="解锁网易云灰色歌曲" href="/cgi-bin/luci/admin/services/unblockmusic">解锁网易云灰色歌曲</a></li><li><a data-title="动态 DNS" href="/cgi-bin/luci/admin/services/ddns">动态 DNS</a></li><li><a data-title="SmartDNS" href="/cgi-bin/luci/admin/services/smartdns">SmartDNS</a></li><li><a data-title="网络唤醒" href="/cgi-bin/luci/admin/services/wol">网络唤醒</a></li><li><a data-title="Frp 内网穿透" href="/cgi-bin/luci/admin/services/frp">Frp 内网穿透</a></li><li><a data-title="UPnP" href="/cgi-bin/luci/admin/services/upnp">UPnP</a></li><li><a data-title="KMS 服务器" href="/cgi-bin/luci/admin/services/vlmcsd">KMS 服务器</a></li><li><a data-title="Nps 内网穿透" href="/cgi-bin/luci/admin/services/nps">Nps 内网穿透</a></li><li><a data-title="MWAN3 分流助手" href="/cgi-bin/luci/admin/services/mwan3helper">MWAN3 分流助手</a></li></ul></li><li class="slide"><a class="menu" data-title="VPN" href="#">VPN</a><ul class="slide-menu"><li><a data-title="PassWall" href="/cgi-bin/luci/admin/vpn/passwall">PassWall</a></li><li><a data-title="ZeroTier" href="/cgi-bin/luci/admin/vpn/zerotier">ZeroTier</a></li></ul></li><li class="slide"><a class="menu" data-title="网络" href="#">网络</a><ul class="slide-menu"><li><a data-title="接口" href="/cgi-bin/luci/admin/network/network">接口</a></li><li><a data-title="无线" href="/cgi-bin/luci/admin/network/wifi">无线</a></li><li><a data-title="DHCP/DNS" href="/cgi-bin/luci/admin/network/dhcp">DHCP/DNS</a></li><li><a data-title="主机名" href="/cgi-bin/luci/admin/network/hosts">主机名</a></li><li>< ...
#  </div>
#  <div class="main-right">
#  <div class="darkMask"></div>
#  <div id="maincontent">
#  <div class="container">
#  <noscript>
#  <div class="alert-message warning">
#  <strong>需要 JavaScript！</strong><br/>
#  						必须开启浏览器的 JavaScript 支持，否则 LuCI 无法正常工作。
#  					</div>
#  </noscript>
#  <script src="/luci-static/resources/cbi.js?v=git-20.191.36863-eee6bae" type="text/javascript"></script>
#  <script type="text/javascript">//<![CDATA[
#  	function progressbar(v, m)
#  	{
#  		var vn = parseInt(v) || 0;
#  		var mn = parseInt(m) || 100;
#  		var pc = Math.floor((100 / mn) * vn);
#
#  		return String.format(
#  			'<div style="width:200px; position:relative; border:1px solid #999999">' +
#  				'<div style="background-color:#CCCCCC; width:%d%%; height:15px">' +
#  					'<div style="position:absolute; left:0; top:0; text-align:center; width:100%%; color:#000000">' +
#  						'<small>%s / %s (%d%%)</small>' +
#  					'</div>' +
#  				'</div>' +
#  			'</div>', pc, v, m, pc
#  		);
#  	}
#
#  	function wifirate(bss, rx) {
#  		var p = rx ? 'rx_' : 'tx_',
#  		    s = '%.1f Mbit/s, %dMHz'
#  					.format(bss[p+'rate'] / 1000, bss[p+'mhz']),
#  		    ht = bss[p+'ht'], vht = bss[p+'vht'],
#  			mhz = bss[p+'mhz'], nss = bss[p+'nss'],
#  			mcs = bss[p+'mcs'], sgi = bss[p+'short_gi'];
#
#  		if (ht || vht) {
#  			if (vht) s += ', VHT-MCS %d'.format(mcs);
#  			if (nss) s += ', VHT-NSS %d'.format(nss);
#  			if (ht)  s += ', MCS %s'.format(mcs);
#  			if (sgi) s += ', Short GI';
#  		}
#
#  		return s;
#  	}
#
#  	function duid2mac(duid) {
#  		// DUID-LLT / Ethernet
#  		if (duid.length === 28 && duid.substr(0, 8) === '00010001')
#  			return duid.substr(16).replace(/(..)(?=..)/g, '$1:').toUpperCase();
#
#  		// DUID-LL / Ethernet
#  		if (duid.length === 20 && duid.substr(0, 8) === '00030001')
#  			return duid.substr(8).replace(/(..)(?=..)/g, '$1:').toUpperCase();
#
#  		return null;
#  	}
#
#  	var npoll = 1;
#  	var hosts = {"EA:D9:F9:1D:EC:91":{"name":"nova_7_SE_5G-8c009ebe7070","ipv4":"192.168.0.228"},"CA:63:37:0A:CB:08":{"name":"HUAWEI_P30-5e39dfb998f95b","ipv4":"192.168.0.215"},"48:51:C5:F2:B8:27":{"ipv6":"fe80::8570:c448:fae1:113d"},"B0:45:02:84:E3:E3":{"name":"HUAWEI_P50_Pro-472b596736","ipv4":"192.168.0.102"},"28:D1:27:DD:1C:21":{"ipv6":"fe80::2ad1:27ff:fedd:1c21","ipv4":"192.168.2.1"},"FC:AA:14:ED:97:81":{"name":"NTPRTH5I5F0SLHF","ipv4":"192.168.0.131"},"FC:D9:08:53:88:04":{"ipv4":"192.168.0.231"},"FE:47:66:34:E0:EC":{"ipv6":"fe80::2fad:2143:31b1:96c7","name":"HONOR_30_Lite-14026a59d68","ipv4":"192.168.0.225"},"06:39:51:96:AA:62":{"ipv4":"192.168.0.223"},"EC:D0:9F:88:27:E1":{"ipv6":"fe80::eed0:9fff:fe88:27e1"},"00:24:68:72:90:80":{"ipv4":"119.34.0.1"},"D2:19:D3:EA:AF:8C":{"ipv6":"fe80::d019:d3ff:feea:af8c"},"CE:23:79:4B:47:58":{"name":"RedmiK20Pro-Redmi","ipv4":"192.168.0.211"},"B0:4A:39:05:9D:C8":{"ipv4":"192.168.0.230"},"30:B2:37:2F:55:EF":{"ipv4":"192.168.0.105"},"6A:84:6A:0E:C3:24":{"ipv4":"192.168.0.226"},"52:B7:03:B6:F2:FD":{"ipv6":"fe80::182e:c016:67a9:2678","ipv4":"192.168.0.102"},"7A:81:56:D2:B9:3C":{"name":"shouhirkiiPhone","ipv4":"192.168.0.229"},"54:A7:03:B6:F2:14":{"ipv6":"fe80::56a7:3ff:feb6:f214","ipv4":"119.34.0.3"},"A2:20:BF:E4:DA:20":{"ipv6":"fe80::1c5a:f02a:9e40:9a04","name":"wenyanfdeiPhone","ipv4":"192.168.0.224"},"54:A7:03:B6:F2:FD":{"ipv4":"192.168.0.109"},"88:BF:E4:17:5B:23":{"ipv6":"fe80::8abf:e4ff:fe17:5b23","name":"HUAWEI_nova_3-c9ca6a342de","ipv4":"192.168.0.227"},"76:CA:37:A8:8F:B9":{"name":"iPad","ipv4":"192.168.0.171"},"00:11:32:6D:BF:0F":{"name":"DS3617","ipv4":"192.168.2.250"},"AC:12:03:A0:54:56":{"name":"DESKTOP-BO34D12","ipv4":"192.168.0.196"}};
#
#  	function updateHosts() {
#  		XHR.get('/cgi-bin/luci/', { hosts: 1 }, function(x, data) {
#  			hosts = data;
#  		});
#  	}
#
#  	XHR.poll(5, '/cgi-bin/luci/', { status: 1 },
#  		function(x, info)
#  		{
#  			if (!(npoll++ % 5))
#  				updateHosts();
#
#  			var si = document.getElementById('wan4_i');
#  			var ss = document.getElementById('wan4_s');
#  			var ifc = info.wan;
#
#  			if (ifc && ifc.ifname && ifc.proto != 'none')
#  			{
#  				var s = String.format(
#  					'<strong>类型: </strong>%s<br />' +
#  					'<strong>地址: </strong>%s<br />' +
#  					'<strong>子网掩码: </strong>%s<br />' +
#  					'<strong>网关: </strong>%s<br />',
#  						ifc.proto,
#  						(ifc.ipaddr) ? ifc.ipaddr : '0.0.0.0',
#  						(ifc.netmask && ifc.netmask != ifc.ipaddr) ? ifc.netmask : '255.255.255.255',
#  						(ifc.gwaddr) ? ifc.gwaddr : '0.0.0.0'
#  				);
#
#  				for (var i = 0; i < ifc.dns.length; i++)
#  				{
#  					s += String.format(
#  						'<strong>DNS %d: </strong>%s<br />',
#  						i + 1, ifc.dns[i]
#  					);
#  				}
#
#  				if (ifc.expires > -1)
#  				{
#  					s += String.format(
#  						'<strong>到期时间: </strong>%t<br />',
#  						ifc.expires
#  					);
#  				}
#
#  				if (ifc.uptime > 0)
#  				{
#  					s += String.format(
#  						'<strong>已连接: </strong>%t<br />',
#  						ifc.uptime
#  					);
#  				}
#
#  				ss.innerHTML = String.format('<small>%s</small>', s);
#  				si.innerHTML = String.format(
#  					'<img src="/luci-static/resources/icons/ethernet.png" />' +
#  					'<br /><small><a href="%s">%s</a></small>',
#  						ifc.link, ifc.ifname
#  				);
#  			}
#  			else
#  			{
#  				si.innerHTML = '<img src="/luci-static/resources/icons/ethernet_disabled.png" /><br /><small>?</small>';
#  				ss.innerHTML = '<em>未连接</em>';
#  			}
#
#
#  			var si6 = document.getElementById('wan6_i');
#  			var ss6 = document.getElementById('wan6_s');
#  			var ifc6 = info.wan6;
#
#  			if (ifc6 && ifc6.ifname && ifc6.proto != 'none')
#  			{
#  				var s = String.format(
#  					'<strong>类型: </strong>%s%s<br />',
#  						ifc6.proto, (ifc6.ip6prefix) ? '-pd' : ''
#  				);
#
#  				if (!ifc6.ip6prefix)
#  				{
#  					s += String.format(
#  						'<strong>地址: </strong>%s<br />',
#  						(ifc6.ip6addr) ? ifc6.ip6addr : '::'
#  					);
#  				}
#  				else
#  				{
#  					s += String.format(
#  						'<strong>分发前缀: </strong>%s<br />',
#  						ifc6.ip6prefix
#  					);
#  					if (ifc6.ip6addr)
#  					{
#  						s += String.format(
#  							'<strong>地址: </strong>%s<br />',
#  							ifc6.ip6addr
#  						);
#  					}
#  				}
#
#  				s += String.format(
#  					'<strong>网关: </strong>%s<br />',
#  						(ifc6.gw6addr) ? ifc6.gw6addr : '::'
#  				);
#
#  				for (var i = 0; i < ifc6.dns.length; i++)
#  				{
#  					s += String.format(
#  						'<strong>DNS %d: </strong>%s<br />',
#  						i + 1, ifc6.dns[i]
#  					);
#  				}
#
#  				if (ifc6.uptime > 0)
#  				{
#  					s += String.format(
#  						'<strong>已连接: </strong>%t<br />',
#  						ifc6.uptime
#  					);
#  				}
#
#  				ss6.innerHTML = String.format('<small>%s</small>', s);
#  				si6.innerHTML = String.format(
#  					'<img src="/luci-static/resources/icons/ethernet.png" />' +
#  					'<br /><small><a href="%s">%s</a></small>',
#  						ifc6.link, ifc6.ifname
#  				);
#  			}
#  			else
#  			{
#  				si6.innerHTML = '<img src="/luci-static/resources/icons/ethernet_disabled.png" /><br /><small>?</small>';
#  				ss6.innerHTML = '<em>未连接</em>';
#  			}
#
#
#
#
#
#  			var ls = document.getElementById('lease_status_table');
#  			if (ls)
#  			{
#  				/* clear all rows */
#  				while( ls.rows.length > 1 )
#  					ls.rows[0].parentNode.deleteRow(1);
#
#  				for( var i = 0; i < info.leases.length; i++ )
#  				{
#  					var timestr;
#
#  					if (info.leases[i].expires === false)
#  						timestr = '<em>无限制</em>';
#  					else if (info.leases[i].expires <= 0)
#  						timestr = '<em>过期时间</em>';
#  					else
#  						timestr = String.format('%t', info.leases[i].expires);
#
#  					var tr = ls.rows[0].parentNode.insertRow(-1);
#  						tr.className = 'cbi-section-table-row cbi-rowstyle-' + ((i % 2) + 1);
#
#  					tr.insertCell(-1).innerHTML = info.leases[i].hostname ? info.leases[i].hostname : '?';
#  					tr.insertCell(-1).innerHTML = info.leases[i].ipaddr;
#  					tr.insertCell(-1).innerHTML = info.leases[i].macaddr;
#  					tr.insertCell(-1).innerHTML = timestr;
#  				}
#
#  				if( ls.rows.length == 1 )
#  				{
#  					var tr = ls.rows[0].parentNode.insertRow(-1);
#  						tr.className = 'cbi-section-table-row';
#
#  					var td = tr.insertCell(-1);
#  						td.colSpan = 4;
#  						td.innerHTML = '<em><br />没有已分配的租约。</em>';
#  				}
#  			}
#
#  			var ls6 = document.getElementById('lease6_status_table');
#  			if (ls6 && info.leases6)
#  			{
#  				ls6.parentNode.style.display = 'block';
#
#  				/* clear all rows */
#  				while( ls6.rows.length > 1 )
#  					ls6.rows[0].parentNode.deleteRow(1);
#
#  				for( var i = 0; i < info.leases6.length; i++ )
#  				{
#  					var timestr;
#
#  					if (info.leases6[i].expires === false)
#  						timestr = '<em>无限制</em>';
#  					else if (info.leases6[i].expires <= 0)
#  						timestr = '<em>过期时间</em>';
#  					else
#  						timestr = String.format('%t', info.leases6[i].expires);
#
#  					var tr = ls6.rows[0].parentNode.insertRow(-1);
#  						tr.className = 'cbi-section-table-row cbi-rowstyle-' + ((i % 2) + 1);
#
#  					var host = hosts[duid2mac(info.leases6[i].duid)];
#  					if (!info.leases6[i].hostname)
#  						tr.insertCell(-1).innerHTML =
#  							(host && (host.name || host.ipv4 || host.ipv6))
#  								? '<div style="max-width:200px;overflow:hidden;text-overflow:ellipsis;white-space: nowrap">? (%h)</div>'.format(host.name || host.ipv4 || host.ipv6)
#  								: '?';
#  					else
#  						tr.insertCell(-1).innerHTML =
#  							(host && host.name && info.leases6[i].hostname != host.name)
#  								? '<div style="max-width:200px;overflow:hidden;text-overflow:ellipsis;white-space: nowrap">%h (%h)</div>'.format(info.leases6[i].hostname, host.name)
#  								: info.leases6[i].hostname;
#
#  					tr.insertCell(-1).innerHTML = info.leases6[i].ip6addr;
#  					tr.insertCell(-1).innerHTML = info.leases6[i].duid;
#  					tr.insertCell(-1).innerHTML = timestr;
#  				}
#
#  				if( ls6.rows.length == 1 )
#  				{
#  					var tr = ls6.rows[0].parentNode.insertRow(-1);
#  						tr.className = 'cbi-section-table-row';
#
#  					var td = tr.insertCell(-1);
#  						td.colSpan = 4;
#  						td.innerHTML = '<em><br />没有已分配的租约。</em>';
#  				}
#  			}
#
#
#
#
#  			var e;
#
#  			if (e = document.getElementById('localtime'))
#  				e.innerHTML = info.localtime;
#
#  			if (e = document.getElementById('uptime'))
#  				e.innerHTML = String.format('%t', info.uptime);
#
#  			if (e = document.getElementById('userinfo'))
#  				e.innerHTML = info.userinfo;
#
#  			if (e = document.getElementById('cpuusage'))
#  				e.innerHTML = info.cpuusage;
#
#  			if (e = document.getElementById('loadavg'))
#  				e.innerHTML = String.format(
#  					'%.02f, %.02f, %.02f',
#  					info.loadavg[0] / 65535.0,
#  					info.loadavg[1] / 65535.0,
#  					info.loadavg[2] / 65535.0
#  				);
#
#  			if (e = document.getElementById('memtotal'))
#  				e.innerHTML = progressbar(
#  					Math.floor(((info.memory.free + info.memory.buffered) / 1048576) + (info.memcached / 1024)) + " MB",
#  					Math.floor(info.memory.total / 1048576) + " MB"
#  				);
#
#  			if (e = document.getElementById('membuff'))
#  				e.innerHTML = progressbar(
#  					Math.floor(info.memory.buffered / 1048576) + " MB",
#  					Math.floor(info.memory.total / 1048576) + " MB"
#  				);
#
#  			if (e = document.getElementById('swaptotal'))
#  				e.innerHTML = progressbar(
#  					Math.floor(info.swap.free / 1048576) + " MB",
#  					Math.floor(info.swap.total / 1048576) + " MB"
#  				);
#
#  			if (e = document.getElementById('swapfree'))
#  				e.innerHTML = progressbar(
#  					Math.floor(info.swap.free / 1048576) + " MB",
#  					Math.floor(info.swap.total / 1048576) + " MB"
#  				);
#
#  			if (e = document.getElementById('conns'))
#  				e.innerHTML = progressbar(info.conncount, info.connmax);
#
#  		}
#  	);
#  //]]></script>
#  <h2 name="content">状态</h2>
#  <fieldset class="cbi-section">
#  <legend>系统</legend>
#  <table cellspacing="10" width="100%">
#  <tr><td width="33%">主机名</td><td>MiRouter</td></tr>
#  <tr><td width="33%">主机型号</td><td>Xiaomi Redmi Router AC2100 (CpuMark : 3746.633884
#   Scores)
#  </td></tr>
#  <tr><td width="33%">架构</td><td>MediaTek MT7621 ver:1 eco:3 x 4
#  </td></tr>
#  <tr><td width="33%">固件版本</td><td>
#  			 OpenWrt  R20.7.7/hfy166 Ver.D200710 /
#  			LuCI Master (git-20.191.36863-eee6bae)
#  		</td></tr>
#  <tr><td width="33%">内核版本</td><td>5.4.50</td></tr>
#  <tr><td width="33%">本地时间</td><td id="localtime">-</td></tr>
#  <tr><td width="33%">运行时间</td><td id="uptime">-</td></tr>
#  <tr><td width="33%">平均负载</td><td id="loadavg">-</td></tr>
#  <tr><td width="33%">CPU 使用率（%）</td><td id="cpuusage">-</td></tr>
#  </table>
#  </fieldset>
#  <fieldset class="cbi-section">
#  <legend>内存</legend>
#  <table cellspacing="10" width="100%">
#  <tr><td width="33%">可用数</td><td id="memtotal">-</td></tr>
#  <tr><td width="33%">已缓存</td><td id="membuff">-</td></tr>
#  </table>
#  </fieldset>
#  <fieldset class="cbi-section">
#  <legend>网络</legend>
#  <table cellspacing="10" width="100%">
#  <tr><td style="vertical-align:top" width="33%">IPv4 WAN 状态</td><td>
#  <table><tr>
#  <td id="wan4_i" style="width:16px; text-align:center; padding:3px"><img src="/luci-static/resources/icons/ethernet_disabled.png"/><br/><small>?</small></td>
#  <td id="wan4_s" style="vertical-align:middle; padding: 3px"><em>正在收集数据...</em></td>
#  </tr></table>
#  </td></tr>
#  <tr><td style="vertical-align:top" width="33%">IPv6 WAN 状态</td><td>
#  <table><tr>
#  <td id="wan6_i" style="width:16px; text-align:center; padding:3px"><img src="/luci-static/resources/icons/ethernet_disabled.png"/><br/><small>?</small></td>
#  <td id="wan6_s" style="vertical-align:middle; padding: 3px"><em>正在收集数据...</em></td>
#  </tr></table>
#  </td></tr>
#  <tr><td width="33%">在线用户数</td><td id="userinfo">0</td></tr>
#  <tr><td width="33%">活动连接</td><td id="conns">-</td></tr>
#  </table>
#  </fieldset>
#  <fieldset class="cbi-section">
#  <legend>DHCP 分配</legend>
#  <table class="cbi-section-table" id="lease_status_table">
#  <tr class="cbi-section-table-titles">
#  <th class="cbi-section-table-cell">主机名</th>
#  <th class="cbi-section-table-cell">IPv4 地址</th>
#  <th class="cbi-section-table-cell">MAC 地址</th>
#  <th class="cbi-section-table-cell">剩余租期</th>
#  </tr>
#  <tr class="cbi-section-table-row">
#  <td colspan="4"><em><br/>正在收集数据...</em></td>
#  </tr>
#  </table>
#  </fieldset>
#  <fieldset class="cbi-section" style="display:none">
#  <legend>DHCPv6 分配</legend>
#  <table class="cbi-section-table" id="lease6_status_table">
#  <tr class="cbi-section-table-titles">
#  <th class="cbi-section-table-cell">主机</th>
#  <th class="cbi-section-table-cell">IPv6 地址</th>
#  <th class="cbi-section-table-cell">DUID</th>
#  <th class="cbi-section-table-cell">剩余租期</th>
#  </tr>
#  <tr class="cbi-section-table-row">
#  <td colspan="4"><em><br/>正在收集数据...</em></td>
#  </tr>
#  </table>
#  </fieldset>
#  </div>
#  <footer class="mobile-hide">
#  <a href="https://github.com/openwrt/luci">Powered by LuCI Master (git-20.191.36863-eee6bae)</a> /
#                      OpenWrt  R20.7.7/hfy166 Ver.D200710
#
#                  </footer>
#  </div>
#  </div>
#  <script>
#          // thanks for Jo-Philipp Wich <jow@openwrt.org>
#          var luciLocation = ["admin","status","overview"];
#      </script>
#  <script src="/luci-static/argon/js/script.js?v=1.0"></script>
#  </div></body>
#  </html>,
#  '\n']

# %%
s.cookies
# Out:
# <RequestsCookieJar[Cookie(version=0, name='sysauth', value='5acb6a02b009a6ce5e99e9f7ee4b4e5e', port=None, port_specified=False, domain='guyf.tk', domain_specified=False, domain_initial_dot=False, path='/cgi-bin/luci/', path_specified=True, secure=False, expires=None, discard=True, comment=None, comment_url=None, rest={}, rfc2109=False)]>

# %%
res1=s.get(url=url)
res1.encoding=res1.apparent_encoding

# %%
soup=BeautifulSoup(res1.text,features="lxml")

# %%
soup.contents
# Out:
# ['html',
#  <html lang="zh-cn">
#  <head>
#  <meta charset="utf-8"/>
#  <title>MiRouter - 网络唤醒 - LuCI</title>
#  <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=0" name="viewport"/>
#  <meta content="telephone=no, email=no" name="format-detection"/>
#  <meta content="yes" name="apple-mobile-web-app-capable"/>
#  <meta content="yes" name="mobile-web-app-capable"/>
#  <meta content="true" name="x5-fullscreen"/>
#  <meta content="yes" name="full-screen"/>
#  <meta content="app" name="x5-page-mode"/>
#  <meta content="application" name="browsermode"/>
#  <meta content="#282828" name="theme-color"/>
#  <meta content="no" name="msapplication-tap-highlight"/>
#  <meta content="#282828" name="msapplication-TileColor"/>
#  <meta content="MiRouter - LuCI" name="application-name"/>
#  <meta content="MiRouter - LuCI" name="apple-mobile-web-app-title"/>
#  <meta content="/luci-static/argon/logo.png" name="msapplication-TileImage"/>
#  <link href="/luci-static/argon/logo.png" rel="icon" sizes="144x144"/>
#  <link href="/luci-static/argon/logo.png" rel="apple-touch-icon-precomposed" sizes="144x144"/>
#  <link href="/luci-static/argon/css/style.css?v=1.0" rel="stylesheet"/>
#  <link href="/luci-static/argon/favicon.ico" rel="shortcut icon"/>
#  <script src="/luci-static/resources/xhr.js?v=1.0"></script>
#  <script src="/luci-static/argon/js/jquery.min.js?v=1.0"></script>
#  </head>
#  <body class="lang_zh-cnWake on LAN logged-in">
#  <header>
#  <div class="container">
#  <span class="showSide"></span>
#  <a class="brand" href="#">MiRouter</a>
#  <div class="pull-right">
#  <a class="uci_change_indicator label notice" href="/cgi-bin/luci/admin/uci/changes?redir=admin%2fservices%2fwol">未保存的配置: 5</a>
#  <span id="xhr_poll_status" onclick="XHR.running() ? XHR.halt() : XHR.run()" style="display:none">
#  <span class="label success" id="xhr_poll_status_on"><span class="mobile-hide">自动刷新</span> 开</span>
#  <span class="label" id="xhr_poll_status_off" style="display:none"><span class="mobile-hide">自动刷新</span> 关</span>
#  </span>
#  </div>
#  </div>
#  </header>
#  <div class="main">
#  <div class="loading" style="display:none"><span><div class="loading-img"></div>Loading...</span></div>
#  <div class="main-left">
#  <ul class="nav"><li class="slide"><a class="menu" data-title="状态" href="#">状态</a><ul class="slide-menu"><li><a data-title="概览" href="/cgi-bin/luci/admin/status/overview">概览</a></li><li><a data-title="防火墙" href="/cgi-bin/luci/admin/status/iptables">防火墙</a></li><li><a data-title="路由表" href="/cgi-bin/luci/admin/status/routes">路由表</a></li><li><a data-title="系统日志" href="/cgi-bin/luci/admin/status/syslog">系统日志</a></li><li><a data-title="内核日志" href="/cgi-bin/luci/admin/status/dmesg">内核日志</a></li><li><a data-title="系统进程" href="/cgi-bin/luci/admin/status/processes">系统进程</a></li><li><a data-title="实时信息" href="/cgi-bin/luci/admin/status/realtime">实时信息</a></li><li><a data-title="负载均衡" href="/cgi-bin/luci/admin/status/mwan">负载均衡</a></li><li><a data-title="释放内存" href="/cgi-bin/luci/admin/status/release_ram">释放内存</a></li></ul></li><li class="slide"><a class="menu" data-title="系统" href="#">系统</a><ul class="slide-menu"><li><a data-title="Web 管理" href="/cgi-bin/luci/admin/system/webadmin">Web 管理</a></li><li><a data-title="系统" href="/cgi-bin/luci/admin/system/system">系统</a></li><li><a data-title="管理权" href="/cgi-bin/luci/admin/system/admin">管理权</a></li><li><a data-title="软件包" href="/cgi-bin/luci/admin/system/packages">软件包</a></li><li><a data-title="TTYD 终端" href="/cgi-bin/luci/admin/system/terminal">TTYD 终端</a></li><li><a data-title="启动项" href="/cgi-bin/luci/admin/system/startup">启动项</a></li><li><a data-title="计划任务" href="/cgi-bin/luci/admin/system/crontab">计划任务</a></li><li><a data-title="挂载点" href="/cgi-bin/luci/admin/system/fstab">挂载点</a></li><li><a data-title="LED 配置" href="/cgi-bin/luci/admin/system/leds">LED 配置</a></li><li><a data-title="备份/升级" href="/cgi-bin/luci/admin/system/flashops">备份/升级</a></li><li><a data-title="定时重启" href="/cgi-bin/luci/admin/system/autoreboot">定时重启</a></li><li><a data-title="文件传输" href="/cgi-bin/luci/admin/system/filetransfer">文件传输</a></li><li><a data-title="重启" href="/cgi-bin/luci/admin/system/reboot">重启</a></li></ul></li><li class="slide"><a class="menu" data-title="服务" href="#">服务</a><ul class="slide-menu"><li><a data-title="广告屏蔽大师 Plus+" href="/cgi-bin/luci/admin/services/adbyby">广告屏蔽大师 Plus+</a></li><li><a data-title="AdGuard Home" href="/cgi-bin/luci/admin/services/AdGuardHome">AdGuard Home</a></li><li><a data-title="Hello World" href="/cgi-bin/luci/admin/services/vssr">Hello World</a></li><li><a data-title="上网时间控制" href="/cgi-bin/luci/admin/services/mia">上网时间控制</a></li><li><a data-title="OpenClash" href="/cgi-bin/luci/admin/services/openclash">OpenClash</a></li><li><a data-title="解锁网易云灰色歌曲" href="/cgi-bin/luci/admin/services/unblockmusic">解锁网易云灰色歌曲</a></li><li><a data-title="动态 DNS" href="/cgi-bin/luci/admin/services/ddns">动态 DNS</a></li><li><a data-title="SmartDNS" href="/cgi-bin/luci/admin/services/smartdns">SmartDNS</a></li><li><a data-title="网络唤醒" href="/cgi-bin/luci/admin/services/wol">网络唤醒</a></li><li><a data-title="Frp 内网穿透" href="/cgi-bin/luci/admin/services/frp">Frp 内网穿透</a></li><li><a data-title="UPnP" href="/cgi-bin/luci/admin/services/upnp">UPnP</a></li><li><a data-title="KMS 服务器" href="/cgi-bin/luci/admin/services/vlmcsd">KMS 服务器</a></li><li><a data-title="Nps 内网穿透" href="/cgi-bin/luci/admin/services/nps">Nps 内网穿透</a></li><li><a data-title="MWAN3 分流助手" href="/cgi-bin/luci/admin/services/mwan3helper">MWAN3 分流助手</a></li></ul></li><li class="slide"><a class="menu" data-title="VPN" href="#">VPN</a><ul class="slide-menu"><li><a data-title="PassWall" href="/cgi-bin/luci/admin/vpn/passwall">PassWall</a></li><li><a data-title="ZeroTier" href="/cgi-bin/luci/admin/vpn/zerotier">ZeroTier</a></li></ul></li><li class="slide"><a class="menu" data-title="网络" href="#">网络</a><ul class="slide-menu"><li><a data-title="接口" href="/cgi-bin/luci/admin/network/network">接口</a></li><li><a data-title="无线" href="/cgi-bin/luci/admin/network/wifi">无线</a></li><li><a data-title="DHCP/DNS" href="/cgi-bin/luci/admin/network/dhcp">DHCP/DNS</a></li><li><a data-title="主机名" href="/cgi-bin/luci/admin/network/hosts">主机名</a></li><li>< ...
#  </div>
#  <div class="main-right">
#  <div class="darkMask"></div>
#  <div id="maincontent">
#  <div class="container">
#  <noscript>
#  <div class="alert-message warning">
#  <strong>需要 JavaScript！</strong><br/>
#  						必须开启浏览器的 JavaScript 支持，否则 LuCI 无法正常工作。
#  					</div>
#  </noscript>
#  <form action="/cgi-bin/luci/admin/services/wol" data-strings='{"path":{"resource":"\/luci-static\/resources","browser":"\/cgi-bin\/luci\/admin\/filebrowser"},"label":{"choose":"-- 请选择 --","custom":"-- 自定义 --"}}' enctype="multipart/form-data" method="post">
#  <div>
#  <script src="/luci-static/resources/cbi.js?v=git-20.191.36863-eee6bae" type="text/javascript"></script>
#  <input name="token" type="hidden" value="33d4bae8a0f8a77358a5a870024a2cf2"/>
#  <input name="cbi.submit" type="hidden" value="1"/>
#  </div>
#  <div class="cbi-map" id="cbi-wol">
#  <h2 name="content">网络唤醒</h2>
#  <div class="cbi-map-descr">网络唤醒是一个远程启动本地网络内计算机的机制。</div>
#  <fieldset class="cbi-section">
#  <div class="cbi-section-node">
#  <div id="cbi-wol-0x9c77a0">
#  <div class="cbi-value" data-depends="[]" data-index="1" id="cbi-wol-1-binary"><label class="cbi-value-title" for="cbid.wol.1.binary">网络唤醒程序</label>
#  <div class="cbi-value-field">
#  <select class="cbi-input-select" data-update="change" id="cbid.wol.1.binary" name="cbid.wol.1.binary" size="1">
#  <option data-depends="[]" data-index="1" id="cbid.wol.1.binary-/usr/bin/etherwake" value="/usr/bin/etherwake">Etherwake</option><option data-depends="[]" data-index="2" id="cbid.wol.1.binary-/usr/bin/wol" value="/usr/bin/wol">WoL</option>
#  </select>
#  <br/>
#  <div class="cbi-value-description">
#  <span class="cbi-value-helpicon"><img alt="帮助" src="/luci-static/resources/cbi/help.gif"/></span>
#  				有时只有一个工具生效。如果其中一个失效，请尝试另一个
#  			</div></div></div>
#  <div class="cbi-value" data-depends='[{"cbid.wol.1.binary":"\/usr\/bin\/etherwake"}]' data-index="2" id="cbi-wol-1-iface"><label class="cbi-value-title" for="cbid.wol.1.iface">选择使用的网络接口</label>
#  <div class="cbi-value-field">
#  <select class="cbi-input-select" data-update="change" id="cbid.wol.1.iface" name="cbid.wol.1.iface" size="1">
#  <option data-depends="[]" data-index="1" id="cbid.wol.1.iface-" value="">向所有接口广播</option><option data-depends="[]" data-index="2" id="cbid.wol.1.iface-eth0" value="eth0">eth0</option><option data-depends="[]" data-index="3" id="cbid.wol.1.iface-wan" value="wan">wan</option><option data-depends="[]" data-index="4" id="cbid.wol.1.iface-lan1" value="lan1">lan1</option><option data-depends="[]" data-index="5" id="cbid.wol.1.iface-lan2" value="lan2">lan2</option><option data-depends="[]" data-index="6" id="cbid.wol.1.iface-lan3" value="lan3">lan3</option><option data-depends="[]" data-index="7" id="cbid.wol.1.iface-ra0" value="ra0">ra0</option><option data-depends="[]" data-index="8" id="cbid.wol.1.iface-rai0" value="rai0">rai0</option><option data-depends="[]" data-index="9" id="cbid.wol.1.iface-sit0" value="sit0">sit0</option><option data-depends="[]" data-index="10" id="cbid.wol.1.iface-br-lan" selected="selected" value="br-lan">br-lan</option><option data-depends="[]" data-index="11" id="cbid.wol.1.iface-apcli0" value="apcli0">apcli0</option><option data-depends="[]" data-index="12" id="cbid.wol.1.iface-apcli1" value="apcli1">apcli1</option><option data-depends="[]" data-index="13" id="cbid.wol.1.iface-wdsi0" value="wdsi0">wdsi0</option><option data-depends="[]" data-index="14" id="cbid.wol.1.iface-wdsi1" value="wdsi1">wdsi1</option><option data-depends="[]" data-index="15" id="cbid.wol.1.iface-wdsi2" value="wdsi2">wdsi2</option><option data-depends="[]" data-index="16" id="cbid.wol.1.iface-wdsi3" value="wdsi3">wdsi3</option><option data-depends="[]" data-index="17" id="cbid.wol.1.iface-apclii0" value="apclii0">apclii0</option>
#  </select>
#  <br/>
#  <div class="cbi-value-description">
#  <span class="cbi-value-helpicon"><img alt="帮助" src="/luci-static/resources/cbi/help.gif"/></span>
#  				限定将发送网络唤醒数据包的接口
#  			</div></div></div>
#  <div class="cbi-value cbi-value-last" data-depends="[]" data-index="3" id="cbi-wol-1-mac"><label class="cbi-value-title" for="cbid.wol.1.mac">选择要唤醒的主机</label>
#  <div class="cbi-value-field">
#  <input class="cbi-input-text" data-choices='[["00:11:32:6D:BF:0F","00:24:68:72:90:80","06:39:51:96:AA:62","28:D1:27:DD:1C:21","30:B2:37:2F:55:EF","52:B7:03:B6:F2:FD","54:A7:03:B6:F2:14","54:A7:03:B6:F2:FD","6A:84:6A:0E:C3:24","76:CA:37:A8:8F:B9","7A:81:56:D2:B9:3C","88:BF:E4:17:5B:23","A2:20:BF:E4:DA:20","AC:12:03:A0:54:56","B0:45:02:84:E3:E3","B0:4A:39:05:9D:C8","CA:63:37:0A:CB:08","CE:23:79:4B:47:58","EA:D9:F9:1D:EC:91","FC:AA:14:ED:97:81","FC:D9:08:53:88:04","FE:47:66:34:E0:EC"],["00:11:32:6D:BF:0F (DS3617)","00:24:68:72:90:80 (119.34.0.1)","06:39:51:96:AA:62 (192.168.0.223)","28:D1:27:DD:1C:21 (192.168.2.1)","30:B2:37:2F:55:EF (192.168.0.105)","52:B7:03:B6:F2:FD (192.168.0.102)","54:A7:03:B6:F2:14 (119.34.0.3)","54:A7:03:B6:F2:FD (192.168.0.109)","6A:84:6A:0E:C3:24 (192.168.0.226)","76:CA:37:A8:8F:B9 (iPad)","7A:81:56:D2:B9:3C (shouhirkiiPhone)","88:BF:E4:17:5B:23 (HUAWEI_nova_3-c9ca6a342de)","A2:20:BF:E4:DA:20 (wenyanfdeiPhone)","AC:12:03:A0:54:56 (DESKTOP-BO34D12)","B0:45:02:84:E3:E3 (HUAWEI_P50_Pro-472b596736)","B0:4A:39:05:9D:C8 (192.168.0.230)","CA:63:37:0A:CB:08 (HUAWEI_P30-5e39dfb998f95b)","CE:23:79:4B:47:58 (RedmiK20Pro-Redmi)","EA:D9:F9:1D:EC:91 (nova_7_SE_5G-8c009ebe7070)","FC:AA:14:ED:97:81 (NTPRTH5I5F0SLHF)","FC:D9:08:53:88:04 (192.168.0.231)","FE:47:66:34:E0:EC (HONOR_30_Lite-14026a59d68)"]]' data-update="change" id="cbid.wol.1.mac" name="cbid.wol.1.mac" type="text" value=""/>
#  <br/>
#  <div class="cbi-value-description">
#  <span class="cbi-value-helpicon"><img alt="帮助" src="/luci-static/resources/cbi/help.gif"/></span>
#  				选择要唤醒的主机，或者输入自定义 MAC 地址
#  			</div></div></div>
#  </div>
#  </div>
#  <br/>
#  </fieldset>
#  <br/>
#  </div>
#  <div class="cbi-page-actions">
#  <input class="cbi-button cbi-button-save" type="submit" value="唤醒主机"/>
#  </div>
#  </form>
#  <script type="text/javascript">cbi_init();</script>
#  </div>
#  <footer class="mobile-hide">
#  <a href="https://github.com/openwrt/luci">Powered by LuCI Master (git-20.191.36863-eee6bae)</a> /
#                      OpenWrt  R20.7.7/hfy166 Ver.D200710
#
#                  </footer>
#  </div>
#  </div>
#  <script>
#          // thanks for Jo-Philipp Wich <jow@openwrt.org>
#          var luciLocation = ["admin","services","wol"];
#      </script>
#  <script src="/luci-static/argon/js/script.js?v=1.0"></script>
#  </div></body>
#  </html>,
#  '\n']

# %%
info = soup.find_all('input',type='hidden')
info
# Out:
# [<input name="token" type="hidden" value="eb6356d410ad5c2daa6664f299eb321e"/>,
#  <input name="cbi.submit" type="hidden" value="1"/>]

# %%
token = info[0]["value"]
submit = info[1]["value"]
# Out:
# '1'

# %%
wolData={
    'token': token,
    "cbi.submit": submit,
    "cbid.wol.1.binary":" /usr/bin/wol",
    "cbid.wol.1.mac": mac
}

# %%
res2=s.post(url=url ,data=wolData)
res2.encoding=res2.apparent_encoding
res2.content
# Out:
# b'<!DOCTYPE html>\n<html lang="zh-cn">\n<head>\n    <meta charset="utf-8">\n    <title>MiRouter - \xe7\xbd\x91\xe7\xbb\x9c\xe5\x94\xa4\xe9\x86\x92 - LuCI</title>\n    <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=0" name="viewport"/>\n    <meta name="format-detection" content="telephone=no, email=no"/>\n    <meta name="apple-mobile-web-app-capable" content="yes">\n    <meta name="mobile-web-app-capable" content="yes">\n    <meta name="x5-fullscreen" content="true">\n    <meta name="full-screen" content="yes">\n    <meta name="x5-page-mode" content="app">\n    <meta name="browsermode" content="application">\n    <meta name="theme-color" content="#282828">\n    <meta name="msapplication-tap-highlight" content="no">\n    <meta name="msapplication-TileColor" content="#282828">\n\n    <meta name="application-name" content="MiRouter - LuCI">\n    <meta name="apple-mobile-web-app-title" content="MiRouter - LuCI">\n    <meta name="msapplication-TileImage" content="/luci-static/argon/logo.png"/>\n    <link rel="icon" href="/luci-static/argon/logo.png" sizes="144x144">\n    <link rel="apple-touch-icon-precomposed" href="/luci-static/argon/logo.png" sizes="144x144">\n\n    <link rel="stylesheet" href="/luci-static/argon/css/style.css?v=1.0">\n    <link rel="shortcut icon" href="/luci-static/argon/favicon.ico">\n    <script src="/luci-static/resources/xhr.js?v=1.0"></script>\n\t<script src="/luci-static/argon/js/jquery.min.js?v=1.0"></script>\n</head>\n<body class="lang_zh-cnWake on LAN logged-in">\n<header>\n\t<div class="container">\n\t\t<span class="showSide"></span>\n\t\t<a class="brand" href="#">MiRouter</a>\n\t\t<div class="pull-right">\n\t\t\t<a class="uci_change_indicator label notice" href="/cgi-bin/luci/admin/uci/changes?redir=admin%2fservices%2fwol">\xe6\x9c\xaa\xe4\xbf\x9d\xe5\xad\x98\xe7\x9a\x84\xe9\x85\x8d\xe7\xbd\xae: 5</a>\n\t\t\t<span id="xhr_poll_status" style="display:none" onclick="XHR.running() ? XHR.halt() : XHR.run()">\n\t\t\t\t<span class="label success" id="xhr_poll_status_on"><span class="mobile-hide">\xe8\x87\xaa\xe5\x8a\xa8\xe5\x88\xb7\xe6\x96\xb0</span> \xe5\xbc\x80</span>\n\t\t\t\t<span class="label" id="xhr_poll_status_off" style="display:none"><span class="mobile-hide">\xe8\x87\xaa\xe5\x8a\xa8\xe5\x88\xb7\xe6\x96\xb0</span> \xe5\x85\xb3</span>\n\t\t\t</span>\n\t\t</div>\n\t</div>\n</header>\n<div class="main">\n\t <div style="display:none" class="loading"><span><div class="loading-img"></div>Loading...</span></div>\n\t <div class="main-left">\n\t\t<ul class="nav"><li class="slide"><a class="menu" data-title="\xe7\x8a\xb6\xe6\x80\x81" href="#">\xe7\x8a\xb6\xe6\x80\x81</a><ul class="slide-menu"><li><a data-title="\xe6\xa6\x82\xe8\xa7\x88" href="/cgi-bin/luci/admin/status/overview">\xe6\xa6\x82\xe8\xa7\x88</a></li><li><a data-title="\xe9\x98\xb2\xe7\x81\xab\xe5\xa2\x99" href="/cgi-bin/luci/admin/status/iptables">\xe9\x98\xb2\xe7\x81\xab\xe5\xa2\x99</a></li><li><a data-title="\xe8\xb7\xaf\xe7\x94\xb1\xe8\xa1\xa8" href="/cgi-bin/luci/admin/status/routes">\xe8\xb7\xaf\xe7\x94\xb1\xe8\xa1\xa8</a></li><li><a data-title="\xe7\xb3\xbb\xe7\xbb\x9f\xe6\x97\xa5\xe5\xbf\x97" href="/cgi-bin/luci/admin/status/syslog">\xe7\xb3\xbb\xe7\xbb\x9f\xe6\x97\xa5\xe5\xbf\x97</a></li><li><a data-title="\xe5\x86\x85\xe6\xa0\xb8\xe6\x97\xa5\xe5\xbf\x97" href="/cgi-bin/luci/admin/status/dmesg">\xe5\x86\x85\xe6\xa0\xb8\xe6\x97\xa5\xe5\xbf\x97</a></li><li><a data-title="\xe7\xb3\xbb\xe7\xbb\x9f\xe8\xbf\x9b\xe7\xa8\x8b" href="/cgi-bin/luci/admin/status/processes">\xe7\xb3\xbb\xe7\xbb\x9f\xe8\xbf\x9b\xe7\xa8\x8b</a></li><li><a data-title="\xe5\xae\x9e\xe6\x97\xb6\xe4\xbf\xa1\xe6\x81\xaf" href="/cgi-bin/luci/admin/status/realtime">\xe5\xae\x9e\xe6\x97\xb6\xe4\xbf\xa1\xe6\x81\xaf</a></li><li><a data-title="\xe8\xb4\x9f\xe8\xbd\xbd\xe5\x9d\x87\xe8\xa1\xa1" href="/cgi-bin/luci/admin/status/mwan">\xe8\xb4\x9f\xe8\xbd\xbd\xe5\x9d\x87\xe8\xa1\xa1</a></li><li><a data-title="\xe9\x87\x8a\xe6\x94\xbe\xe5\x86\x ...

# %%
soup = BeautifulSoup(res2.text,features="lxml")
soup.contents
# Out:
# ['html',
#  <html lang="zh-cn">
#  <head>
#  <meta charset="utf-8"/>
#  <title>MiRouter - 网络唤醒 - LuCI</title>
#  <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=0" name="viewport"/>
#  <meta content="telephone=no, email=no" name="format-detection"/>
#  <meta content="yes" name="apple-mobile-web-app-capable"/>
#  <meta content="yes" name="mobile-web-app-capable"/>
#  <meta content="true" name="x5-fullscreen"/>
#  <meta content="yes" name="full-screen"/>
#  <meta content="app" name="x5-page-mode"/>
#  <meta content="application" name="browsermode"/>
#  <meta content="#282828" name="theme-color"/>
#  <meta content="no" name="msapplication-tap-highlight"/>
#  <meta content="#282828" name="msapplication-TileColor"/>
#  <meta content="MiRouter - LuCI" name="application-name"/>
#  <meta content="MiRouter - LuCI" name="apple-mobile-web-app-title"/>
#  <meta content="/luci-static/argon/logo.png" name="msapplication-TileImage"/>
#  <link href="/luci-static/argon/logo.png" rel="icon" sizes="144x144"/>
#  <link href="/luci-static/argon/logo.png" rel="apple-touch-icon-precomposed" sizes="144x144"/>
#  <link href="/luci-static/argon/css/style.css?v=1.0" rel="stylesheet"/>
#  <link href="/luci-static/argon/favicon.ico" rel="shortcut icon"/>
#  <script src="/luci-static/resources/xhr.js?v=1.0"></script>
#  <script src="/luci-static/argon/js/jquery.min.js?v=1.0"></script>
#  </head>
#  <body class="lang_zh-cnWake on LAN logged-in">
#  <header>
#  <div class="container">
#  <span class="showSide"></span>
#  <a class="brand" href="#">MiRouter</a>
#  <div class="pull-right">
#  <a class="uci_change_indicator label notice" href="/cgi-bin/luci/admin/uci/changes?redir=admin%2fservices%2fwol">未保存的配置: 5</a>
#  <span id="xhr_poll_status" onclick="XHR.running() ? XHR.halt() : XHR.run()" style="display:none">
#  <span class="label success" id="xhr_poll_status_on"><span class="mobile-hide">自动刷新</span> 开</span>
#  <span class="label" id="xhr_poll_status_off" style="display:none"><span class="mobile-hide">自动刷新</span> 关</span>
#  </span>
#  </div>
#  </div>
#  </header>
#  <div class="main">
#  <div class="loading" style="display:none"><span><div class="loading-img"></div>Loading...</span></div>
#  <div class="main-left">
#  <ul class="nav"><li class="slide"><a class="menu" data-title="状态" href="#">状态</a><ul class="slide-menu"><li><a data-title="概览" href="/cgi-bin/luci/admin/status/overview">概览</a></li><li><a data-title="防火墙" href="/cgi-bin/luci/admin/status/iptables">防火墙</a></li><li><a data-title="路由表" href="/cgi-bin/luci/admin/status/routes">路由表</a></li><li><a data-title="系统日志" href="/cgi-bin/luci/admin/status/syslog">系统日志</a></li><li><a data-title="内核日志" href="/cgi-bin/luci/admin/status/dmesg">内核日志</a></li><li><a data-title="系统进程" href="/cgi-bin/luci/admin/status/processes">系统进程</a></li><li><a data-title="实时信息" href="/cgi-bin/luci/admin/status/realtime">实时信息</a></li><li><a data-title="负载均衡" href="/cgi-bin/luci/admin/status/mwan">负载均衡</a></li><li><a data-title="释放内存" href="/cgi-bin/luci/admin/status/release_ram">释放内存</a></li></ul></li><li class="slide"><a class="menu" data-title="系统" href="#">系统</a><ul class="slide-menu"><li><a data-title="Web 管理" href="/cgi-bin/luci/admin/system/webadmin">Web 管理</a></li><li><a data-title="系统" href="/cgi-bin/luci/admin/system/system">系统</a></li><li><a data-title="管理权" href="/cgi-bin/luci/admin/system/admin">管理权</a></li><li><a data-title="软件包" href="/cgi-bin/luci/admin/system/packages">软件包</a></li><li><a data-title="TTYD 终端" href="/cgi-bin/luci/admin/system/terminal">TTYD 终端</a></li><li><a data-title="启动项" href="/cgi-bin/luci/admin/system/startup">启动项</a></li><li><a data-title="计划任务" href="/cgi-bin/luci/admin/system/crontab">计划任务</a></li><li><a data-title="挂载点" href="/cgi-bin/luci/admin/system/fstab">挂载点</a></li><li><a data-title="LED 配置" href="/cgi-bin/luci/admin/system/leds">LED 配置</a></li><li><a data-title="备份/升级" href="/cgi-bin/luci/admin/system/flashops">备份/升级</a></li><li><a data-title="定时重启" href="/cgi-bin/luci/admin/system/autoreboot">定时重启</a></li><li><a data-title="文件传输" href="/cgi-bin/luci/admin/system/filetransfer">文件传输</a></li><li><a data-title="重启" href="/cgi-bin/luci/admin/system/reboot">重启</a></li></ul></li><li class="slide"><a class="menu" data-title="服务" href="#">服务</a><ul class="slide-menu"><li><a data-title="广告屏蔽大师 Plus+" href="/cgi-bin/luci/admin/services/adbyby">广告屏蔽大师 Plus+</a></li><li><a data-title="AdGuard Home" href="/cgi-bin/luci/admin/services/AdGuardHome">AdGuard Home</a></li><li><a data-title="Hello World" href="/cgi-bin/luci/admin/services/vssr">Hello World</a></li><li><a data-title="上网时间控制" href="/cgi-bin/luci/admin/services/mia">上网时间控制</a></li><li><a data-title="OpenClash" href="/cgi-bin/luci/admin/services/openclash">OpenClash</a></li><li><a data-title="解锁网易云灰色歌曲" href="/cgi-bin/luci/admin/services/unblockmusic">解锁网易云灰色歌曲</a></li><li><a data-title="动态 DNS" href="/cgi-bin/luci/admin/services/ddns">动态 DNS</a></li><li><a data-title="SmartDNS" href="/cgi-bin/luci/admin/services/smartdns">SmartDNS</a></li><li><a data-title="网络唤醒" href="/cgi-bin/luci/admin/services/wol">网络唤醒</a></li><li><a data-title="Frp 内网穿透" href="/cgi-bin/luci/admin/services/frp">Frp 内网穿透</a></li><li><a data-title="UPnP" href="/cgi-bin/luci/admin/services/upnp">UPnP</a></li><li><a data-title="KMS 服务器" href="/cgi-bin/luci/admin/services/vlmcsd">KMS 服务器</a></li><li><a data-title="Nps 内网穿透" href="/cgi-bin/luci/admin/services/nps">Nps 内网穿透</a></li><li><a data-title="MWAN3 分流助手" href="/cgi-bin/luci/admin/services/mwan3helper">MWAN3 分流助手</a></li></ul></li><li class="slide"><a class="menu" data-title="VPN" href="#">VPN</a><ul class="slide-menu"><li><a data-title="PassWall" href="/cgi-bin/luci/admin/vpn/passwall">PassWall</a></li><li><a data-title="ZeroTier" href="/cgi-bin/luci/admin/vpn/zerotier">ZeroTier</a></li></ul></li><li class="slide"><a class="menu" data-title="网络" href="#">网络</a><ul class="slide-menu"><li><a data-title="接口" href="/cgi-bin/luci/admin/network/network">接口</a></li><li><a data-title="无线" href="/cgi-bin/luci/admin/network/wifi">无线</a></li><li><a data-title="DHCP/DNS" href="/cgi-bin/luci/admin/network/dhcp">DHCP/DNS</a></li><li><a data-title="主机名" href="/cgi-bin/luci/admin/network/hosts">主机名</a></li><li>< ...
#  </div>
#  <div class="main-right">
#  <div class="darkMask"></div>
#  <div id="maincontent">
#  <div class="container">
#  <noscript>
#  <div class="alert-message warning">
#  <strong>需要 JavaScript！</strong><br/>
#  						必须开启浏览器的 JavaScript 支持，否则 LuCI 无法正常工作。
#  					</div>
#  </noscript>
#  <form action="/cgi-bin/luci/admin/services/wol" data-strings='{"path":{"resource":"\/luci-static\/resources","browser":"\/cgi-bin\/luci\/admin\/filebrowser"},"label":{"choose":"-- 请选择 --","custom":"-- 自定义 --"}}' enctype="multipart/form-data" method="post">
#  <div>
#  <script src="/luci-static/resources/cbi.js?v=git-20.191.36863-eee6bae" type="text/javascript"></script>
#  <input name="token" type="hidden" value="eb6356d410ad5c2daa6664f299eb321e"/>
#  <input name="cbi.submit" type="hidden" value="1"/>
#  </div>
#  <div class="cbi-map" id="cbi-wol">
#  <h2 name="content">网络唤醒</h2>
#  <div class="cbi-map-descr">网络唤醒是一个远程启动本地网络内计算机的机制。</div>
#  <fieldset class="cbi-section">
#  <div class="cbi-section-node">
#  <div id="cbi-wol-0x9a8ba0">
#  <div class="cbi-value cbi-value-error" data-depends="[]" data-index="1" id="cbi-wol-1-binary"><label class="cbi-value-title" for="cbid.wol.1.binary">网络唤醒程序</label>
#  <div class="cbi-value-field">
#  <select class="cbi-input-select" data-update="change" id="cbid.wol.1.binary" name="cbid.wol.1.binary" size="1">
#  <option data-depends="[]" data-index="1" id="cbid.wol.1.binary-/usr/bin/etherwake" value="/usr/bin/etherwake">Etherwake</option><option data-depends="[]" data-index="2" id="cbid.wol.1.binary-/usr/bin/wol" value="/usr/bin/wol">WoL</option>
#  </select>
#  <br/>
#  <div class="cbi-value-description">
#  <span class="cbi-value-helpicon"><img alt="帮助" src="/luci-static/resources/cbi/help.gif"/></span>
#  				有时只有一个工具生效。如果其中一个失效，请尝试另一个
#  			</div></div></div>
#  <div class="cbi-value" data-depends='[{"cbid.wol.1.binary":"\/usr\/bin\/etherwake"}]' data-index="2" id="cbi-wol-1-iface"><label class="cbi-value-title" for="cbid.wol.1.iface">选择使用的网络接口</label>
#  <div class="cbi-value-field">
#  <select class="cbi-input-select" data-update="change" id="cbid.wol.1.iface" name="cbid.wol.1.iface" size="1">
#  <option data-depends="[]" data-index="1" id="cbid.wol.1.iface-" value="">向所有接口广播</option><option data-depends="[]" data-index="2" id="cbid.wol.1.iface-eth0" value="eth0">eth0</option><option data-depends="[]" data-index="3" id="cbid.wol.1.iface-wan" value="wan">wan</option><option data-depends="[]" data-index="4" id="cbid.wol.1.iface-lan1" value="lan1">lan1</option><option data-depends="[]" data-index="5" id="cbid.wol.1.iface-lan2" value="lan2">lan2</option><option data-depends="[]" data-index="6" id="cbid.wol.1.iface-lan3" value="lan3">lan3</option><option data-depends="[]" data-index="7" id="cbid.wol.1.iface-ra0" value="ra0">ra0</option><option data-depends="[]" data-index="8" id="cbid.wol.1.iface-rai0" value="rai0">rai0</option><option data-depends="[]" data-index="9" id="cbid.wol.1.iface-sit0" value="sit0">sit0</option><option data-depends="[]" data-index="10" id="cbid.wol.1.iface-br-lan" selected="selected" value="br-lan">br-lan</option><option data-depends="[]" data-index="11" id="cbid.wol.1.iface-apcli0" value="apcli0">apcli0</option><option data-depends="[]" data-index="12" id="cbid.wol.1.iface-apcli1" value="apcli1">apcli1</option><option data-depends="[]" data-index="13" id="cbid.wol.1.iface-wdsi0" value="wdsi0">wdsi0</option><option data-depends="[]" data-index="14" id="cbid.wol.1.iface-wdsi1" value="wdsi1">wdsi1</option><option data-depends="[]" data-index="15" id="cbid.wol.1.iface-wdsi2" value="wdsi2">wdsi2</option><option data-depends="[]" data-index="16" id="cbid.wol.1.iface-wdsi3" value="wdsi3">wdsi3</option><option data-depends="[]" data-index="17" id="cbid.wol.1.iface-apclii0" value="apclii0">apclii0</option>
#  </select>
#  <br/>
#  <div class="cbi-value-description">
#  <span class="cbi-value-helpicon"><img alt="帮助" src="/luci-static/resources/cbi/help.gif"/></span>
#  				限定将发送网络唤醒数据包的接口
#  			</div></div></div>
#  <div class="cbi-value cbi-value-last" data-depends="[]" data-index="3" id="cbi-wol-1-mac"><label class="cbi-value-title" for="cbid.wol.1.mac">选择要唤醒的主机</label>
#  <div class="cbi-value-field">
#  <input class="cbi-input-text" data-choices='[["00:11:32:6D:BF:0F","00:24:68:72:90:80","06:39:51:96:AA:62","28:D1:27:DD:1C:21","30:B2:37:2F:55:EF","52:B7:03:B6:F2:FD","54:A7:03:B6:F2:14","54:A7:03:B6:F2:FD","6A:84:6A:0E:C3:24","76:CA:37:A8:8F:B9","7A:81:56:D2:B9:3C","88:BF:E4:17:5B:23","A2:20:BF:E4:DA:20","AC:12:03:A0:54:56","B0:45:02:84:E3:E3","B0:4A:39:05:9D:C8","CA:63:37:0A:CB:08","CE:23:79:4B:47:58","EA:D9:F9:1D:EC:91","FC:AA:14:ED:97:81","FC:D9:08:53:88:04","FE:47:66:34:E0:EC"],["00:11:32:6D:BF:0F (DS3617)","00:24:68:72:90:80 (119.34.0.1)","06:39:51:96:AA:62 (192.168.0.223)","28:D1:27:DD:1C:21 (192.168.2.1)","30:B2:37:2F:55:EF (192.168.0.105)","52:B7:03:B6:F2:FD (192.168.0.102)","54:A7:03:B6:F2:14 (119.34.0.3)","54:A7:03:B6:F2:FD (192.168.0.109)","6A:84:6A:0E:C3:24 (192.168.0.226)","76:CA:37:A8:8F:B9 (iPad)","7A:81:56:D2:B9:3C (shouhirkiiPhone)","88:BF:E4:17:5B:23 (HUAWEI_nova_3-c9ca6a342de)","A2:20:BF:E4:DA:20 (wenyanfdeiPhone)","AC:12:03:A0:54:56 (DESKTOP-BO34D12)","B0:45:02:84:E3:E3 (HUAWEI_P50_Pro-472b596736)","B0:4A:39:05:9D:C8 (192.168.0.230)","CA:63:37:0A:CB:08 (HUAWEI_P30-5e39dfb998f95b)","CE:23:79:4B:47:58 (RedmiK20Pro-Redmi)","EA:D9:F9:1D:EC:91 (nova_7_SE_5G-8c009ebe7070)","FC:AA:14:ED:97:81 (NTPRTH5I5F0SLHF)","FC:D9:08:53:88:04 (192.168.0.231)","FE:47:66:34:E0:EC (HONOR_30_Lite-14026a59d68)"]]' data-update="change" id="cbid.wol.1.mac" name="cbid.wol.1.mac" type="text" value=""/>
#  <br/>
#  <div class="cbi-value-description">
#  <span class="cbi-value-helpicon"><img alt="帮助" src="/luci-static/resources/cbi/help.gif"/></span>
#  				选择要唤醒的主机，或者输入自定义 MAC 地址
#  			</div></div></div>
#  </div>
#  <div class="cbi-section-error">
#  <ul><li>一个或多个选项值有误！</li></ul>
#  </div>
#  </div>
#  <br/>
#  </fieldset>
#  <br/>
#  </div>
#  <div><p><strong>正在启动网络唤醒工具：</strong><br/><br/><code> /usr/bin/wol -v "00:11:32:6D:BF:0F"<br/><br/>Waking up 00:11:32:6D:BF:0F with 255.255.255.255:40000...<br/></code></p></div>
#  <div class="cbi-page-actions">
#  <input class="cbi-button cbi-button-save" type="submit" value="唤醒主机"/>
#  </div>
#  </form>
#  <script type="text/javascript">cbi_init();</script>
#  </div>
#  <footer class="mobile-hide">
#  <a href="https://github.com/openwrt/luci">Powered by LuCI Master (git-20.191.36863-eee6bae)</a> /
#                      OpenWrt  R20.7.7/hfy166 Ver.D200710
#
#                  </footer>
#  </div>
#  </div>
#  <script>
#          // thanks for Jo-Philipp Wich <jow@openwrt.org>
#          var luciLocation = ["admin","services","wol"];
#      </script>
#  <script src="/luci-static/argon/js/script.js?v=1.0"></script>
#  </div></body>
#  </html>,
#  '\n']

# %%
str(soup.find("p")).split('<br/>')[-2]
# Out:
# 'Waking up 00:11:32:6D:BF:0F with 255.255.255.255:40000...'
